# %%
import nltk 
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
f = open('News_Article_2016_Jan.csv','rb')
raw = f.read()
raw = raw.decode("utf-8")
raw = raw.replace('\n',' ')

# %%
#Tokenization
tokens = nltk.word_tokenize(raw)

#Stopwords Removal and only keep text data then change to lowercase
mystopwords = stopwords.words('english')
words = [w.lower() for w in tokens if w.isalpha() if w.lower()not in mystopwords]

# %%
tokens
# Out:
# ['Day',
#  ',',
#  'Name',
#  ',',
#  'Year',
#  ',',
#  'month',
#  ',',
#  'Content',
#  '21,3D',
#  'SYSTEMS,2016',
#  ',',
#  'January',
#  ',',
#  "''",
#  'Plastics',
#  'News',
#  'Print',
#  'Version',
#  'January',
#  '18',
#  ',',
#  '2016',
#  '3-D',
#  'printing',
#  'and',
#  'surgery',
#  'a',
#  "'paradigm",
#  'shift',
#  "'",
#  'BYLINE',
#  ':',
#  'Caroline',
#  'Lewis',
#  'SECTION',
#  ':',
#  'Pg',
#  '.',
#  '13',
#  'Vol',
#  '.',
#  '27',
#  'LENGTH',
#  ':',
#  '1608',
#  'words',
#  'DATELINE',
#  ':',
#  'New',
#  'York',
#  'Zeesy',
#  'Stern',
#  'lay',
#  'unconscious',
#  'on',
#  'an',
#  'operating',
#  'table',
#  'at',
#  'New',
#  'York',
#  'University',
#  'Langone',
#  'Medical',
#  'Center',
#  'as',
#  'a',
#  'surgeon',
#  'removed',
#  'a',
#  'section',
#  'of',
#  'her',
#  'jaw',
#  'where',
#  'a',
#  'golf-ball-size',
#  'tumor',
#  'had',
#  'begun',
#  'to',
#  'displace',
#  'the',
#  'teeth',
#  'on',
#  'the',
#  'left',
#  'side',
#  'of',
#  'her',
#  'mouth',
#  '.',
#  'Another',
#  'doctor',
#  ',',
#  'meanwhile',
#  ',',
#  'worked',
#  'to',
#  'extract',
#  'a',
#  'piece',
#  'of',
#  'her',
#  'fibula',
#  'that',
#  'would',
#  'be',
#  'fitted',
#  'like',
#  'a',
#  'puzzle',
#  'piece',
#  'into',
#  'the',
#  'space',
#  'where',
#  'her',
#  'jaw',
#  'once',
#  'was',
#  '.',
#  'The',
#  'goal',
#  'was',
#  'to',
#  'remove',
#  'the',
#  'growth',
#  'and',
#  'create',
#  'a',
#  'new',
#  ',',
#  'fully',
#  'functioning',
#  'jaw',
#  ',',
#  'a',
#  'feat',
#  'that',
#  'once',
#  'took',
#  'three',
#  'operations',
#  'over',
#  '18',
#  'months',
#  'and',
#  'left',
#  'some',
#  'patients',
#  'with',
#  'trouble',
#  'chewing',
#  'and',
#  'disfigurement',
#  '.',
#  'But',
#  'the',
#  'doctors',
#  'at',
#  'NYU',
#  'Langone',
#  'had',
#  'pioneered',
#  'a',
#  'new',
#  'approach',
#  ',',
#  'one',
#  'they',
#  'dubbed',
#  '``',
#  "''",
#  'jaw',
#  'in',
#  'a',
#  'day',
#  '.',
#  "''",
#  "''",
#  'The',
#  'tool',
#  'that',
#  'made',
#  'it',
#  'possible',
#  ':',
#  'not',
#  'a',
#  'scalpel',
#  ',',
#  'but',
#  'a',
#  '3-D',
#  'printer',
#  '.',
#  '``',
#  '``',
#  'It',
#  "'s",
#  'a',
#  'paradigm',
#  'shift',
#  'in',
#  'the',
#  'way',
#  'of',
#  'doing',
#  'surgery',
#  ',',
#  "''",
#  "''",
#  'said',
#  'Dr.',
#  'Jamie',
#  'Levine',
#  ',',
#  'chief',
#  'of',
#  'microsurgery',
#  'at',
#  'NYU',
#  'Langone',
#  ',',
#  'and',
#  'one',
#  'of',
#  'the',
#  'surgeons',
#  'who',
#  'worked',
#  'on',
#  'Stern',
#  '.',
#  '``',
#  '``',
#  'There',
#  'was',
#  'a',
#  'need',
#  'for',
#  'it',
#  'to',
#  'be',
#  'more',
#  'precise',
#  '.',
#  "''",
#  "''",
#  'The',
#  'Institute',
#  'for',
#  'Reconstructive',
#  'Plastic',
#  'Surgery',
#  'at',
#  'NYU',
#  'Langone',
#  'is',
#  'one',
#  'of',
#  'a',
#  'growing',
#  'number',
#  'of',
#  'New',
#  'York',
#  'hospital',
#  'departments',
#  'that',
#  'have',
#  'embraced',
#  'the',
#  'use',
#  'of',
#  '3-D',
#  'printing',
#  ',',
#  'in',
#  'which',
#  'materials',
#  'such',
#  'as',
#  'plastic',
#  'or',
#  'titanium',
#  'powder',
#  'are',
#  'exuded',
#  ',',
#  'layer',
#  'by',
#  'layer',
#  ',',
#  'to',
#  'create',
#  'objects',
#  ':',
#  'jewelry',
#  ',',
#  'kitchen',
#  'utensils',
#  'or',
#  ',',
#  'say',
#  ',',
#  'a',
#  'new',
#  'trachea',
#  '.',
#  'The',
#  'surgeons',
#  'at',
#  'NYU',
#  'Langone',
#  'use',
#  'the',
#  'printers',
#  'to',
#  'better',
#  'plan',
#  'and',
#  'execute',
#  'complex',
#  'procedures',
#  'like',
#  'Stern',
#  "'s",
#  'with',
#  'more',
#  'precision',
#  'and',
#  'predictability',
#  ',',
#  'ultimately',
#  'saving',
#  'hours',
#  'in',
#  'the',
#  'operating',
#  'room',
#  'and',
#  '$',
#  '20,000',
#  'to',
#  '$',
#  '30,000',
#  'per',
#  'reconstruction',
#  '.',
#  'Medical',
#  'growth',
#  'The',
#  'promise',
#  'of',
#  '3-D',
#  'printing',
#  'is',
#  'a',
#  'world',
#  'of',
#  'science',
#  'fiction',
#  'come',
#  'to',
#  'life',
#  ':',
#  'Headlines',
#  'from',
#  '2015',
#  'included',
#  'the',
#  'first',
#  '3-D-printed',
#  'nose',
#  'in',
#  'the',
#  'U.S.',
#  ',',
#  'created',
#  'by',
#  'a',
#  'doctor',
#  'at',
#  'the',
#  'New',
#  'York',
#  'Eye',
#  'and',
#  'Ear',
#  'Infirmary',
#  'of',
#  'Mount',
#  'Sinai',
#  '.',
#  'Last',
#  'year',
#  'also',
#  'saw',
#  'Food',
#  'and',
#  'Drug',
#  'Administration',
#  'approval',
#  'for',
#  '3-D-printed',
#  'pills',
#  'and',
#  'vertebrae',
#  '.',
#  'Designs',
#  'for',
#  'bionic',
#  'hands',
#  'are',
#  'now',
#  'available',
#  'for',
#  'free',
#  'on',
#  'the',
#  'Internet',
#  ',',
#  'and',
#  'researchers',
#  'from',
#  'around',
#  'the',
#  'world',
#  'are',
#  'experimenting',
#  'with',
#  'organs',
#  'printed',
#  'from',
#  'living',
#  'cells',
#  '.',
#  'The',
#  'genius',
#  'of',
#  '3-D',
#  'printing',
#  'is',
#  'that',
#  ',',
#  'unlike',
#  'traditional',
#  'manufacturing',
#  ',',
#  'complex',
#  'objects',
#  'are',
#  'not',
#  'more',
#  'expensive',
#  'to',
#  'make',
#  ';',
#  'they',
#  'do',
#  'not',
#  'require',
#  'unique',
#  'molds',
#  'or',
#  'multiple',
#  'machines',
#  '.',
#  'The',
#  'cost',
#  'of',
#  'any',
#  'object',
#  'is',
#  'determined',
#  'simply',
#  'by',
#  'the',
#  'amount',
#  'of',
#  'printing',
#  'material',
#  'used',
#  'and',
#  'the',
#  'time',
#  'needed',
#  'to',
#  'design',
#  'it',
#  'on',
#  'a',
#  'computer',
#  '.',
#  'Medical-grade',
#  'printers',
#  'are',
#  'expensive',
#  ',',
#  'some',
#  'costing',
#  'upward',
#  'of',
#  '$',
#  '200,000',
#  '.',
#  'But',
#  'one',
#  'printer',
#  'can',
#  'make',
#  'an',
#  'infinite',
#  'number',
#  'of',
#  'objects',
#  'customized',
#  'to',
#  'each',
#  'individual',
#  "'s",
#  'anatomy',
#  '.',
#  'And',
#  'the',
#  'cost',
#  'of',
#  'printers',
#  'is',
#  'starting',
#  'to',
#  'come',
#  'down',
#  '.',
#  'A',
#  'Philadelphia',
#  'company',
#  'called',
#  'BioBots',
#  'made',
#  'waves',
#  'last',
#  'year',
#  'by',
#  'releasing',
#  'a',
#  '$',
#  '10,000',
#  'bioprinter',
#  ',',
#  'which',
#  'it',
#  'offered',
#  'for',
#  '$',
#  '5,000',
#  'to',
#  'scientists',
#  'for',
#  'testing',
#  '.',
#  'In',
#  'Stern',
#  "'s",
#  'case',
#  ',',
#  'her',
#  'doctors',
#  'designed',
#  'a',
#  'metal',
#  'plate',
#  'and',
#  'plastic',
#  'surgical',
#  'guides',
#  '-',
#  'indicating',
#  'where',
#  'to',
#  'cut',
#  'or',
#  'drill',
#  '-',
#  'based',
#  'on',
#  'a',
#  'digital',
#  '3-D',
#  'model',
#  'of',
#  'her',
#  'skull',
#  'made',
#  'from',
#  'CAT-scan',
#  'images',
#  '.',
#  'The',
#  'pieces',
#  'were',
#  'manufactured',
#  'by',
#  '3D',
#  'Systems',
#  ',',
#  'a',
#  'South',
#  'Carolina',
#  'company',
#  'whose',
#  'founder',
#  ',',
#  'Chuck',
#  'Hull',
#  ',',
#  'patented',
#  'the',
#  'first',
#  '3-D',
#  'printer',
#  'in',
#  '1986',
#  '.',
#  'Though',
#  '3D',
#  'Systems',
#  'would',
#  'not',
#  'disclose',
#  'its',
#  'costs',
#  ',',
#  'the',
#  'plastic',
#  'in',
#  'each',
#  'of',
#  'Stern',
#  "'s",
#  'surgical',
#  'guides',
#  'retails',
#  'for',
#  'just',
#  'a',
#  'few',
#  'dollars',
#  '.',
#  '``',
#  '``',
#  'That',
#  "'s",
#  'the',
#  'whole',
#  'secret',
#  'of',
#  '3-D',
#  'printing',
#  ',',
#  "''",
#  "''",
#  'said',
#  'Katherine',
#  'Weimer',
#  ',',
#  'vice',
#  'president',
#  'of',
#  'medical',
#  'devices',
#  'at',
#  '3D',
#  'Systems',
#  '.',
#  '``',
#  '``',
#  'Complexity',
#  'is',
#  'free',
#  '.',
#  "''",
#  "''",
#  'Despite',
#  'the',
#  'potential',
#  'for',
#  'innovation',
#  ',',
#  'medical',
#  '3-D',
#  'printing',
#  ',',
#  'as',
#  'Stern',
#  'learned',
#  ',',
#  'is',
#  'only',
#  'just',
#  'beginning',
#  'to',
#  'be',
#  'adopted',
#  'in',
#  'New',
#  'York',
#  '.',
#  'Stern',
#  'received',
#  'her',
#  'initial',
#  'diagnosis',
#  'from',
#  'an',
#  'oral',
#  'surgeon',
#  'who',
#  'was',
#  'unaware',
#  'of',
#  '3-D',
#  'printing',
#  "'s",
#  'advances',
#  ',',
#  'telling',
#  'her',
#  'that',
#  'her',
#  'only',
#  'option',
#  'was',
#  'a',
#  'lengthy',
#  ',',
#  'three-surgery',
#  'ordeal',
#  '.',
#  'During',
#  'much',
#  'of',
#  'that',
#  'time',
#  ',',
#  'he',
#  'said',
#  ',',
#  'Stern',
#  'would',
#  'be',
#  'left',
#  'with',
#  'a',
#  'seriously',
#  'diminished',
#  'set',
#  'of',
#  'teeth',
#  '.',
#  'The',
#  'prospect',
#  'gave',
#  'the',
#  'usually',
#  'calm',
#  '38-year-old',
#  'special-education',
#  'teacher',
#  'an',
#  'uncharacteristic',
#  'dose',
#  'of',
#  'anxiety',
#  '.',
#  '``',
#  '``',
#  'If',
#  'I',
#  'could',
#  'get',
#  'through',
#  'one',
#  'surgery',
#  ',',
#  'I',
#  'would',
#  'still',
#  'have',
#  'to',
#  'get',
#  'through',
#  'the',
#  'next',
#  'and',
#  'the',
#  'next',
#  ',',
#  "''",
#  "''",
#  'said',
#  'Stern',
#  ',',
#  'thinking',
#  'back',
#  'on',
#  'the',
#  'prognosis',
#  '18',
#  'months',
#  'later',
#  'in',
#  'her',
#  'apartment',
#  'in',
#  'New',
#  'York',
#  "'s",
#  'Upper',
#  'West',
#  'Side',
#  '.',
#  '``',
#  '``',
#  'My',
#  'life',
#  'would',
#  'have',
#  'been',
#  'destroyed',
#  'for',
#  'a',
#  'long',
#  'time',
#  '.',
#  "''",
#  "''",
#  'The',
#  'cost',
#  'of',
#  'the',
#  'machines',
#  'is',
#  'only',
#  'one',
#  'hurdle',
#  'to',
#  'wider',
#  'adoption',
#  'of',
#  '3-D',
#  'printing',
#  '.',
#  'The',
#  'learning',
#  'curve',
#  'of',
#  'mastering',
#  'the',
#  'design',
#  'software',
#  'is',
#  'steep',
#  ',',
#  'and',
#  'doctors',
#  'need',
#  'to',
#  'spend',
#  'extra',
#  'time',
#  'planning',
#  'the',
#  'surgery',
#  'and',
#  'designing',
#  'the',
#  'tools',
#  'they',
#  "'ll",
#  'need',
#  'to',
#  'execute',
#  'it',
#  '.',
#  'The',
#  'health',
#  'industry',
#  'is',
#  'also',
#  'mired',
#  'in',
#  'regulatory',
#  ',',
#  'cultural',
#  'and',
#  'institutional',
#  'challenges',
#  'that',
#  'preclude',
#  'rapid',
#  'change',
#  '.',
#  'The',
#  'pioneers',
#  'in',
#  'this',
#  'field',
#  'are',
#  'finding',
#  'that',
#  'insurance',
#  'companies',
#  ',',
#  'as',
#  'well',
#  'as',
#  'patients',
#  'and',
#  'doctors',
#  ',',
#  'must',
#  'be',
#  'made',
#  'to',
#  'understand',
#  'the',
#  'value',
#  'of',
#  '3-D-printed',
#  'devices',
#  'in',
#  'order',
#  'to',
#  'factor',
#  'them',
#  'into',
#  'reimbursement',
#  'rates',
#  '.',
#  'A',
#  'priority',
#  'for',
#  '3D',
#  'Systems',
#  'is',
#  'conducting',
#  'studies',
#  'with',
#  'institutions',
#  'to',
#  'prove',
#  'that',
#  '3-D',
#  'printing',
#  'can',
#  'improve',
#  'health',
#  'outcomes',
#  'and',
#  'save',
#  'money',
#  '.',
#  'As',
#  'doctors',
#  'have',
#  'found',
#  'more',
#  'uses',
#  'for',
#  '3-D',
#  'printing',
#  'over',
#  'the',
#  'past',
#  'decade',
#  ',',
#  'they',
#  'have',
#  'influenced',
#  'the',
#  'materials',
#  'developed',
#  'by',
#  'companies',
#  'such',
#  'as',
#  '3D',
#  'Systems',
#  'and',
#  'Stratasys',
#  ',',
#  'the',
#  'parent',
#  'company',
#  'of',
#  ...]

# %%
words
# Out:
# ['day',
#  'name',
#  'year',
#  'month',
#  'content',
#  'january',
#  'plastics',
#  'news',
#  'print',
#  'version',
#  'january',
#  'printing',
#  'surgery',
#  'shift',
#  'byline',
#  'caroline',
#  'lewis',
#  'section',
#  'pg',
#  'vol',
#  'length',
#  'words',
#  'dateline',
#  'new',
#  'york',
#  'zeesy',
#  'stern',
#  'lay',
#  'unconscious',
#  'operating',
#  'table',
#  'new',
#  'york',
#  'university',
#  'langone',
#  'medical',
#  'center',
#  'surgeon',
#  'removed',
#  'section',
#  'jaw',
#  'tumor',
#  'begun',
#  'displace',
#  'teeth',
#  'left',
#  'side',
#  'mouth',
#  'another',
#  'doctor',
#  'meanwhile',
#  'worked',
#  'extract',
#  'piece',
#  'fibula',
#  'would',
#  'fitted',
#  'like',
#  'puzzle',
#  'piece',
#  'space',
#  'jaw',
#  'goal',
#  'remove',
#  'growth',
#  'create',
#  'new',
#  'fully',
#  'functioning',
#  'jaw',
#  'feat',
#  'took',
#  'three',
#  'operations',
#  'months',
#  'left',
#  'patients',
#  'trouble',
#  'chewing',
#  'disfigurement',
#  'doctors',
#  'nyu',
#  'langone',
#  'pioneered',
#  'new',
#  'approach',
#  'one',
#  'dubbed',
#  'jaw',
#  'day',
#  'tool',
#  'made',
#  'possible',
#  'scalpel',
#  'printer',
#  'paradigm',
#  'shift',
#  'way',
#  'surgery',
#  'said',
#  'jamie',
#  'levine',
#  'chief',
#  'microsurgery',
#  'nyu',
#  'langone',
#  'one',
#  'surgeons',
#  'worked',
#  'stern',
#  'need',
#  'precise',
#  'institute',
#  'reconstructive',
#  'plastic',
#  'surgery',
#  'nyu',
#  'langone',
#  'one',
#  'growing',
#  'number',
#  'new',
#  'york',
#  'hospital',
#  'departments',
#  'embraced',
#  'use',
#  'printing',
#  'materials',
#  'plastic',
#  'titanium',
#  'powder',
#  'exuded',
#  'layer',
#  'layer',
#  'create',
#  'objects',
#  'jewelry',
#  'kitchen',
#  'utensils',
#  'say',
#  'new',
#  'trachea',
#  'surgeons',
#  'nyu',
#  'langone',
#  'use',
#  'printers',
#  'better',
#  'plan',
#  'execute',
#  'complex',
#  'procedures',
#  'like',
#  'stern',
#  'precision',
#  'predictability',
#  'ultimately',
#  'saving',
#  'hours',
#  'operating',
#  'room',
#  'per',
#  'reconstruction',
#  'medical',
#  'growth',
#  'promise',
#  'printing',
#  'world',
#  'science',
#  'fiction',
#  'come',
#  'life',
#  'headlines',
#  'included',
#  'first',
#  'nose',
#  'created',
#  'doctor',
#  'new',
#  'york',
#  'eye',
#  'ear',
#  'infirmary',
#  'mount',
#  'sinai',
#  'last',
#  'year',
#  'also',
#  'saw',
#  'food',
#  'drug',
#  'administration',
#  'approval',
#  'pills',
#  'vertebrae',
#  'designs',
#  'bionic',
#  'hands',
#  'available',
#  'free',
#  'internet',
#  'researchers',
#  'around',
#  'world',
#  'experimenting',
#  'organs',
#  'printed',
#  'living',
#  'cells',
#  'genius',
#  'printing',
#  'unlike',
#  'traditional',
#  'manufacturing',
#  'complex',
#  'objects',
#  'expensive',
#  'make',
#  'require',
#  'unique',
#  'molds',
#  'multiple',
#  'machines',
#  'cost',
#  'object',
#  'determined',
#  'simply',
#  'amount',
#  'printing',
#  'material',
#  'used',
#  'time',
#  'needed',
#  'design',
#  'computer',
#  'printers',
#  'expensive',
#  'costing',
#  'upward',
#  'one',
#  'printer',
#  'make',
#  'infinite',
#  'number',
#  'objects',
#  'customized',
#  'individual',
#  'anatomy',
#  'cost',
#  'printers',
#  'starting',
#  'come',
#  'philadelphia',
#  'company',
#  'called',
#  'biobots',
#  'made',
#  'waves',
#  'last',
#  'year',
#  'releasing',
#  'bioprinter',
#  'offered',
#  'scientists',
#  'testing',
#  'stern',
#  'case',
#  'doctors',
#  'designed',
#  'metal',
#  'plate',
#  'plastic',
#  'surgical',
#  'guides',
#  'indicating',
#  'cut',
#  'drill',
#  'based',
#  'digital',
#  'model',
#  'skull',
#  'made',
#  'images',
#  'pieces',
#  'manufactured',
#  'systems',
#  'south',
#  'carolina',
#  'company',
#  'whose',
#  'founder',
#  'chuck',
#  'hull',
#  'patented',
#  'first',
#  'printer',
#  'though',
#  'systems',
#  'would',
#  'disclose',
#  'costs',
#  'plastic',
#  'stern',
#  'surgical',
#  'guides',
#  'retails',
#  'dollars',
#  'whole',
#  'secret',
#  'printing',
#  'said',
#  'katherine',
#  'weimer',
#  'vice',
#  'president',
#  'medical',
#  'devices',
#  'systems',
#  'complexity',
#  'free',
#  'despite',
#  'potential',
#  'innovation',
#  'medical',
#  'printing',
#  'stern',
#  'learned',
#  'beginning',
#  'adopted',
#  'new',
#  'york',
#  'stern',
#  'received',
#  'initial',
#  'diagnosis',
#  'oral',
#  'surgeon',
#  'unaware',
#  'printing',
#  'advances',
#  'telling',
#  'option',
#  'lengthy',
#  'ordeal',
#  'much',
#  'time',
#  'said',
#  'stern',
#  'would',
#  'left',
#  'seriously',
#  'diminished',
#  'set',
#  'teeth',
#  'prospect',
#  'gave',
#  'usually',
#  'calm',
#  'teacher',
#  'uncharacteristic',
#  'dose',
#  'anxiety',
#  'could',
#  'get',
#  'one',
#  'surgery',
#  'would',
#  'still',
#  'get',
#  'next',
#  'next',
#  'said',
#  'stern',
#  'thinking',
#  'back',
#  'prognosis',
#  'months',
#  'later',
#  'apartment',
#  'new',
#  'york',
#  'upper',
#  'west',
#  'side',
#  'life',
#  'would',
#  'destroyed',
#  'long',
#  'time',
#  'cost',
#  'machines',
#  'one',
#  'hurdle',
#  'wider',
#  'adoption',
#  'printing',
#  'learning',
#  'curve',
#  'mastering',
#  'design',
#  'software',
#  'steep',
#  'doctors',
#  'need',
#  'spend',
#  'extra',
#  'time',
#  'planning',
#  'surgery',
#  'designing',
#  'tools',
#  'need',
#  'execute',
#  'health',
#  'industry',
#  'also',
#  'mired',
#  'regulatory',
#  'cultural',
#  'institutional',
#  'challenges',
#  'preclude',
#  'rapid',
#  'change',
#  'pioneers',
#  'field',
#  'finding',
#  'insurance',
#  'companies',
#  'well',
#  'patients',
#  'doctors',
#  'must',
#  'made',
#  'understand',
#  'value',
#  'devices',
#  'order',
#  'factor',
#  'reimbursement',
#  'rates',
#  'priority',
#  'systems',
#  'conducting',
#  'studies',
#  'institutions',
#  'prove',
#  'printing',
#  'improve',
#  'health',
#  'outcomes',
#  'save',
#  'money',
#  'doctors',
#  'found',
#  'uses',
#  'printing',
#  'past',
#  'decade',
#  'influenced',
#  'materials',
#  'developed',
#  'companies',
#  'systems',
#  'stratasys',
#  'parent',
#  'company',
#  'makerbot',
#  'manufactures',
#  'desktop',
#  'printers',
#  'new',
#  'materials',
#  'years',
#  'ago',
#  'plastics',
#  'could',
#  'printed',
#  'custom',
#  'prosthetics',
#  'manipulated',
#  'surgical',
#  'tools',
#  'titanium',
#  'powder',
#  'loaded',
#  'printers',
#  'produce',
#  'custom',
#  'implants',
#  'mixed',
#  'materials',
#  'opening',
#  'new',
#  'possibilities',
#  'feinstein',
#  'institute',
#  'medical',
#  'research',
#  'long',
#  'island',
#  'experimenting',
#  'something',
#  'makerbot',
#  'calls',
#  'limestone',
#  'material',
#  'actually',
#  'composite',
#  'organic',
#  'plastic',
#  'calcium',
#  'carbonate',
#  'together',
#  'mimics',
#  'bone',
#  'flexible',
#  'materials',
#  'act',
#  'body',
#  'parts',
#  'also',
#  'works',
#  'gain',
#  'fda',
#  'approval',
#  'material',
#  'device',
#  'comes',
#  'contact',
#  'patients',
#  'must',
#  'capable',
#  'sterilized',
#  'challenging',
#  'process',
#  'materials',
#  'go',
#  'something',
#  'printing',
#  'process',
#  'makes',
#  'nonsterile',
#  'said',
#  'weimer',
#  'systems',
#  'said',
#  'fda',
#  'approval',
#  'printed',
#  'products',
#  'becoming',
#  'common',
#  'within',
#  'hospitals',
#  'printing',
#  'capabilities',
#  'vary',
#  'widely',
#  'department',
#  'two',
#  'medical',
#  'units',
#  'nyu',
#  'langone',
#  'printers',
#  'levine',
#  'team',
#  'collaborate',
#  'systems',
#  'using',
#  'company',
#  'printers',
#  'software',
#  'departments',
#  'use',
#  'technology',
#  'oren',
#  'tepper',
#  'director',
#  'craniofacial',
#  'surgery',
#  'montefiore',
#  'medical',
#  'center',
#  'bronx',
#  'using',
#  'technology',
#  'since',
#  'like',
#  'levine',
#  'outsources',
#  'printing',
#  'needs',
#  'systems',
#  'however',
#  'talks',
#  'montefiore',
#  'creating',
#  'printing',
#  'center',
#  'would',
#  'widely',
#  'accessible',
#  'physicians',
#  'hospital',
#  'think',
#  'main',
#  'limitation',
#  'printing',
#  'functionality',
#  'cost',
#  'awareness',
#  'done',
#  'tepper',
#  'said',
#  'majority',
#  'health',
#  'care',
#  'workers',
#  'even',
#  'knowledge',
#  'technology',
#  'exists',
#  'stern',
#  'vaguely',
#  'aware',
#  'printing',
#  'diagnosis',
#  'march',
#  'benign',
#  'tumor',
#  'called',
#  'ameloblastoma',
#  'researching',
#  'second',
#  'opinions',
#  'found',
#  'levine',
#  'team',
#  'surgeons',
#  'nyu',
#  'langone',
#  'soon',
#  'buoyed',
#  'doctors',
#  'confidence',
#  'pictures',
#  'showed',
#  'previous',
#  'patients',
#  'stern',
#  'surgery',
#  'began',
#  'early',
#  'one',
#  'may',
#  'morning',
#  'parents',
#  'sister',
#  'bided',
#  'time',
#  'waiting',
#  'room',
#  'surgical',
#  'team',
#  'removed',
#  'jaw',
#  'cut',
#  'bone',
#  'leg',
#  'careful',
#  'digital',
#  'planning',
#  'cutting',
#  'guides',
#  'fedexed',
#  'systems',
#  'allowed',
#  'doctors',
#  'work',
#  'simultaneously',
#  'knowing',
#  'everything',
#  'would',
#  'match',
#  'end',
#  'implant',
#  'carved',
#  'leg',
#  'fit',
#  'jaw',
#  'perfectly',
#  'true',
#  'titanium',
#  'plate',
#  'surgeons',
#  'designed',
#  'hold',
#  'stern',
#  'new',
#  'jaw',
#  'place',
#  'printing',
#  'entered',
#  'equation',
#  'lot',
#  'eyeballing',
#  'according',
#  'levine',
#  'could',
#  'go',
#  'operating',
#  'room',
#  'metal',
#  'plate',
#  'exact',
#  'size',
#  'shape',
#  'needed',
#  'instead',
#  'manipulate',
#  'standard',
#  'pieces',
#  'metal',
#  'hand',
#  'patient',
#  'sedated',
#  'imagine',
#  'sitting',
#  'set',
#  'pliers',
#  'make',
#  'plate',
#  'fit',
#  'jaw',
#  'somewhat',
#  'said',
#  'daniel',
#  'ceradini',
#  'associate',
#  'director',
#  'microsurgery',
#  'nyu',
#  'langone',
#  'also',
#  'helped',
#  'develop',
#  'procedure',
#  'placement',
#  'plate',
#  'jaw',
#  'implant',
#  'millimeters',
#  'patient',
#  'could',
#  'suffer',
#  'jaw',
#  'implant',
#  'surgeons',
#  'inserted',
#  'screws',
#  'would',
#  'secure',
#  'stern',
#  'new',
#  'dentures',
#  'used',
#  'drilling',
#  'guide',
#  'really',
#  'centimeters',
#  'plastic',
#  'aids',
#  'placement',
#  'screw',
#  'hole',
#  'still',
#  'piece',
#  'plastic',
#  'levine',
#  'ceradini',
#  'insist',
#  'makes',
#  'difference',
#  'eliminating',
#  'guesswork',
#  'could',
#  'lead',
#  'costly',
#  'complications',
#  'stern',
#  'left',
#  'operating',
#  'room',
#  'hours',
#  'disoriented',
#  'dark',
#  'outside',
#  'sister',
#  'turned',
#  'pale',
#  'zeesy',
#  'asked',
#  'father',
#  'stern',
#  'face',
#  'severely',
#  'swollen',
#  'spend',
#  'week',
#  'hospital',
#  'fed',
#  'tube',
#  'throat',
#  'afterward',
#  'stern',
#  'spent',
#  'two',
#  'months',
#  'parents',
#  'house',
#  'embarrassed',
#  'go',
#  'outside',
#  'yet',
#  'receive',
#  'dentures',
#  'three',
#  'months',
#  'though',
#  'back',
#  'work',
#  'despite',
#  'chunk',
#  'bone',
#  'missing',
#  'leg',
#  'running',
#  'kids',
#  'teaches',
#  'preschool',
#  'near',
#  'central',
#  'park',
#  'new',
#  'york',
#  'city',
#  'within',
#  'decade',
#  'levine',
#  'predicts',
#  'printers',
#  'common',
#  'cat',
#  'scans',
#  'novel',
#  'printers',
#  'colleague',
#  'ceradini',
#  'agrees',
#  'looking',
#  'road',
#  'years',
#  'printer',
#  'office',
#  'clinic',
#  'become',
#  'new',
#  'mainstay',
#  'said',
#  'opposed',
#  'one',
#  'company',
#  'prints',
#  'things',
#  'fedexes',
#  'next',
#  'day',
#  'january',
#  'language',
#  'english',
#  'newspaper',
#  'pn',
#  'copyright',
#  'crain',
#  'communications',
#  'rights',
#  'reserved',
#  'january',
#  'us',
#  'official',
#  'news',
#  'january',
#  'monday',
#  'form',
#  'systems',
#  'corp',
#  'files',
#  'current',
#  'report',
#  'length',
#  'words',
#  'dateline',
#  'lahore',
#  'washington',
#  'systems',
#  'corp',
#  'filed',
#  'form',
#  'current',
#  'report',
#  'securities',
#  'exchange',
#  'commission',
#  'january',
#  'systems',
#  'corporation',
#  'exact',
#  'name',
#  'registrant',
#  'specified',
#  'charter',
#  'delaware',
#  'state',
#  'jurisdiction',
#  'commission',
#  'irs',
#  'employer',
#  'incorporation',
#  'file',
#  'number',
#  'identification',
#  'three',
#  'systems',
#  'circle',
#  'rock',
#  'hill',
#  'south',
#  'carolina',
#  'address',
#  'principal',
#  'executive',
#  'offices',
#  'zip',
#  'code',
#  'registrant',
#  'telephone',
#  'number',
#  'including',
#  'area',
#  'code',
#  'former',
#  'name',
#  'former',
#  'address',
#  'changed',
#  'since',
#  'last',
#  'report',
#  'check',
#  'appropriate',
#  'box',
#  'form',
#  'filing',
#  'intended',
#  'simultaneously',
#  'satisfy',
#  'filing',
#  'obligation',
#  'registrant',
#  'following',
#  'provisions',
#  'see',
#  'general',
#  'instruction',
#  'written',
#  'communications',
#  'pursuant',
#  'rule',
#  'securities',
#  'act',
#  'cfr',
#  'soliciting',
#  'material',
#  'pursuant',
#  'rule',
#  'exchange',
#  'act',
#  'cfr',
#  'communications',
#  'pursuant',
#  'rule',
#  'b',
#  'exchange',
#  'act',
#  'cfr',
#  'b',
#  'communications',
#  ...]

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nicolasclarke/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
POS_tags = nltk.pos_tag(tokens) #use unprocessed 'tokens', not 'words'

#Generate a list of POS tags
POS_tag_list = [(word,tag) for (word,tag) in POS_tags if tag.startswith('NNP')]
# if you change N to V you will get all verbs

# %%
tag_freq = nltk.FreqDist(POS_tag_list)
#Sort the result 
sorted_tag_freq = sorted(tag_freq.items(), key = lambda k:k[1], reverse = True)

# %%
sorted_tag_freq
# Out:
# [(('January', 'NNP'), 67722),
#  (('*', 'NNP'), 23219),
#  (('CA', 'NNP'), 21879),
#  (('Inc.', 'NNP'), 21250),
#  (('Copyright', 'NNP'), 19638),
#  (('@', 'NNP'), 18106),
#  (('All', 'NNP'), 17857),
#  (('Rights', 'NNP'), 16559),
#  (('LLC', 'NNP'), 15631),
#  (('Inc', 'NNP'), 13976),
#  (('EMAIL', 'NNP'), 13193),
#  (('ONLY', 'NNP'), 13102),
#  (('LENGTH', 'NNP'), 13100),
#  (('Company', 'NNP'), 12262),
#  (('Commission', 'NNP'), 12208),
#  (('New', 'NNP'), 11146),
#  (('News', 'NNP'), 10724),
#  (('Jan.', 'NNP'), 9694),
#  (('No', 'NNP'), 9236),
#  (('U.S.', 'NNP'), 8952),
#  (('Group', 'NNP'), 8534),
#  (('BYLINE', 'NNP'), 8417),
#  (('US', 'NNP'), 8331),
#  (('Energy', 'NNP'), 7864),
#  (('Newspaper', 'NNP'), 7845),
#  (('A', 'NNP'), 7823),
#  (('SAN', 'NNP'), 7621),
#  (('December', 'NNP'), 7567),
#  (('Media', 'NNP'), 7394),
#  (('ENERGY', 'NNP'), 6553),
#  ((']', 'NNP'), 6497),
#  (('Thursday', 'NNP'), 6368),
#  (('Wednesday', 'NNP'), 6232),
#  (('Pg', 'NNP'), 6060),
#  (('FOR', 'NNP'), 6045),
#  (('Document', 'NNP'), 6034),
#  (('Tuesday', 'NNP'), 6016),
#  (('Court', 'NNP'), 5931),
#  (('County', 'NNP'), 5925),
#  (('Friday', 'NNP'), 5885),
#  (('Limited', 'NNP'), 5875),
#  (('St.', 'NNP'), 5836),
#  (('Bank', 'NNP'), 5812),
#  (('India', 'NNP'), 5733),
#  (('United', 'NNP'), 5664),
#  (('[', 'NNP'), 5564),
#  (('Mr.', 'NNP'), 5539),
#  (('Monday', 'NNP'), 5487),
#  (('OF', 'NNP'), 5485),
#  (('City', 'NNP'), 5480),
#  (('Case', 'NNP'), 5453),
#  (('National', 'NNP'), 5190),
#  (('State', 'NNP'), 5101),
#  (('Service', 'NNP'), 5091),
#  (('Co.', 'NNP'), 5061),
#  (('York', 'NNP'), 4942),
#  (('Solutions', 'NNP'), 4898),
#  (('Corp.', 'NNP'), 4847),
#  (('Web', 'NNP'), 4827),
#  (('FRANCISCO', 'NNP'), 4807),
#  (('Dial', 'NNP'), 4748),
#  (('North', 'NNP'), 4681),
#  (('Agency', 'NNP'), 4644),
#  (('Corporation', 'NNP'), 4541),
#  (('STREET', 'NNP'), 4507),
#  (('California', 'NNP'), 4420),
#  (('Tribune', 'NNP'), 4413),
#  (('International', 'NNP'), 4387),
#  (('Act', 'NNP'), 4385),
#  (('Daily', 'NNP'), 4365),
#  (('John', 'NNP'), 4191),
#  (('F.3d', 'NNP'), 4153),
#  (('Saturday', 'NNP'), 4145),
#  (('DATELINE', 'NNP'), 4125),
#  (('Edition', 'NNP'), 4111),
#  (('Street', 'NNP'), 4076),
#  (('Washington', 'NNP'), 4000),
#  (('CALIFORNIA', 'NNP'), 3986),
#  (('Public', 'NNP'), 3985),
#  (('Market', 'NNP'), 3963),
#  (('States', 'NNPS'), 3952),
#  (('Business', 'NNP'), 3951),
#  (('West', 'NNP'), 3944),
#  (('Private', 'NNP'), 3940),
#  (('Capital', 'NNP'), 3936),
#  (('Center', 'NNP'), 3920),
#  (('Publication', 'NNP'), 3904),
#  (('THE', 'NNP'), 3872),
#  (('China', 'NNP'), 3869),
#  (('AM', 'NNP'), 3866),
#  (('COMPANY', 'NNP'), 3842),
#  (('Department', 'NNP'), 3809),
#  (('Financial', 'NNP'), 3798),
#  (('Id', 'NNP'), 3768),
#  (('South', 'NNP'), 3743),
#  (('Exchange', 'NNP'), 3655),
#  (('Cir', 'NNP'), 3635),
#  (('Dec.', 'NNP'), 3620),
#  (('AND', 'NNP'), 3614),
#  (('CEO', 'NNP'), 3608),
#  (('Health', 'NNP'), 3593),
#  (('General', 'NNP'), 3577),
#  (('Federal', 'NNP'), 3568),
#  (('November', 'NNP'), 3544),
#  (('STE', 'NNP'), 3538),
#  (('America', 'NNP'), 3494),
#  (('Plus', 'NNP'), 3468),
#  (('EST', 'NNP'), 3415),
#  (('President', 'NNP'), 3397),
#  (('District', 'NNP'), 3396),
#  (('University', 'NNP'), 3393),
#  (('Ohio', 'NNP'), 3385),
#  (('Services', 'NNPS'), 3382),
#  (('Ltd', 'NNP'), 3367),
#  (('Official', 'NNP'), 3341),
#  (('Contify.com', 'NNP'), 3341),
#  (('Ltd.', 'NNP'), 3324),
#  (('ENGLISH', 'NNP'), 3315),
#  (('Plaintiff', 'NNP'), 3293),
#  (('Corp', 'NNP'), 3291),
#  (('INC.', 'NNP'), 3250),
#  (('Content', 'NNP'), 3199),
#  (('J', 'NNP'), 3169),
#  (('First', 'NNP'), 3120),
#  (('San', 'NNP'), 3111),
#  (('B', 'NNP'), 3070),
#  (('Sunday', 'NNP'), 3058),
#  (('Board', 'NNP'), 3029),
#  (('Times', 'NNP'), 3022),
#  (('J.', 'NNP'), 3013),
#  (('March', 'NNP'), 3010),
#  (('February', 'NNP'), 2996),
#  (('LLP', 'NNP'), 2975),
#  (('R.', 'NNP'), 2965),
#  (('AVENUE', 'NNP'), 2964),
#  (('COMMISSION', 'NNP'), 2928),
#  (('S', 'NNP'), 2923),
#  (('M', 'NNP'), 2914),
#  (('Gas', 'NNP'), 2883),
#  (('M.', 'NNP'), 2873),
#  (('GAS', 'NNP'), 2862),
#  (('Dr.', 'NNP'), 2847),
#  (('E.', 'NNP'), 2831),
#  (('David', 'NNP'), 2789),
#  (('Texas', 'NNP'), 2777),
#  (('Mr', 'NNP'), 2771),
#  (('October', 'NNP'), 2766),
#  (('SUITE', 'NNP'), 2746),
#  (('Trust', 'NNP'), 2727),
#  (('S.', 'NNP'), 2723),
#  (('School', 'NNP'), 2693),
#  (('Road', 'NNP'), 2662),
#  (('ELECTRIC', 'NNP'), 2648),
#  (('NEWS', 'NNP'), 2628),
#  (('Agreement', 'NNP'), 2608),
#  (('Florida', 'NNP'), 2602),
#  (('SECTION', 'NNP'), 2600),
#  (('East', 'NNP'), 2594),
#  (('Report', 'NNP'), 2581),
#  (('James', 'NNP'), 2538),
#  (('June', 'NNP'), 2505),
#  (('Johnson', 'NNP'), 2504),
#  (('Docket', 'NNP'), 2500),
#  (('P', 'NNP'), 2488),
#  (('Park', 'NNP'), 2486),
#  (('PUBLIC', 'NNP'), 2484),
#  (('Global', 'NNP'), 2482),
#  (('Management', 'NNP'), 2480),
#  (('American', 'NNP'), 2410),
#  (('Electric', 'NNP'), 2406),
#  (('September', 'NNP'), 2399),
#  (('C', 'NNP'), 2398),
#  (('L.', 'NNP'), 2389),
#  (('Smith', 'NNP'), 2378),
#  (('D.', 'NNP'), 2355),
#  (('Power', 'NNP'), 2351),
#  (('Chief', 'NNP'), 2337),
#  (('UTILITIES', 'NNP'), 2335),
#  (('Netflix', 'NNP'), 2333),
#  (('Lahore', 'NNP'), 2331),
#  (('Canada', 'NNP'), 2327),
#  (('Date', 'NNP'), 2321),
#  (('Office', 'NNP'), 2303),
#  (('Valley', 'NNP'), 2274),
#  (('Regulatory', 'NNP'), 2271),
#  (('Jones', 'NNP'), 2233),
#  (('GHz', 'NNP'), 2220),
#  (('July', 'NNP'), 2207),
#  (('London', 'NNP'), 2195),
#  (('Association', 'NNP'), 2186),
#  (('Post', 'NNP'), 2170),
#  (('Michael', 'NNP'), 2151),
#  (('D', 'NNP'), 2149),
#  (('ATTORNEY', 'NNP'), 2142),
#  (('Medical', 'NNP'), 2137),
#  (('Executive', 'NNP'), 2137),
#  (('F.', 'NNP'), 2133),
#  (('May', 'NNP'), 2126),
#  (('WL', 'NNP'), 2112),
#  (('SACRAMENTO', 'NNP'), 2105),
#  (('Plaintiffs', 'NNP'), 2093),
#  (('Morgan', 'NNP'), 2058),
#  (('Order', 'NNP'), 2054),
#  (('April', 'NNP'), 2049),
#  (('Rule', 'NNP'), 2037),
#  (('C.', 'NNP'), 2012),
#  (('Partners', 'NNP'), 2007),
#  (('GRAPHIC', 'NNP'), 1991),
#  (('Drive', 'NNP'), 1973),
#  (('W.', 'NNP'), 1968),
#  (('Complete', 'NNP'), 1968),
#  (('DIEGO', 'NNP'), 1964),
#  (('Co', 'NNP'), 1938),
#  (('Director', 'NNP'), 1936),
#  (('T', 'NNP'), 1925),
#  (('Insurance', 'NNP'), 1914),
#  (('L', 'NNP'), 1896),
#  (('Paul', 'NNP'), 1894),
#  (('Brown', 'NNP'), 1875),
#  (('Development', 'NNP'), 1875),
#  (('ST.', 'NNP'), 1867),
#  (('Class', 'NNP'), 1855),
#  (('TO', 'NNP'), 1855),
#  (('Officer', 'NNP'), 1847),
#  (('Robert', 'NNP'), 1846),
#  (('R', 'NNP'), 1840),
#  (('Ct.', 'NNP'), 1826),
#  (('USA', 'NNP'), 1822),
#  (('Feb.', 'NNP'), 1822),
#  (('Realty', 'NNP'), 1821),
#  (('Council', 'NNP'), 1820),
#  (('N', 'NNP'), 1814),
#  (('NYSE', 'NNP'), 1813),
#  (('Home', 'NNP'), 1812),
#  (('UK', 'NNP'), 1807),
#  (('>', 'NNP'), 1794),
#  (('Technology', 'NNP'), 1771),
#  (('Australia', 'NNP'), 1769),
#  (('v.', 'NNP'), 1754),
#  (('Press', 'NNP'), 1734),
#  (('Minnesota', 'NNP'), 1692),
#  (('<', 'NNP'), 1677),
#  (('/', 'NNP'), 1672),
#  (('Community', 'NNP'), 1666),
#  (('Investment', 'NNP'), 1653),
#  (('Air', 'NNP'), 1651),
#  (('Healthcare', 'NNP'), 1648),
#  (('II', 'NNP'), 1648),
#  (('Research', 'NNP'), 1645),
#  (('College', 'NNP'), 1626),
#  (('High', 'NNP'), 1623),
#  (('Lake', 'NNP'), 1603),
#  (('Circuit', 'NNP'), 1600),
#  (('Apple', 'NNP'), 1594),
#  (('Star', 'NNP'), 1591),
#  (('Thomas', 'NNP'), 1588),
#  (('Form', 'NNP'), 1582),
#  (('World', 'NNP'), 1582),
#  (('House', 'NNP'), 1559),
#  (('Number', 'NNP'), 1558),
#  (('FERC', 'NNP'), 1550),
#  (('Illinois', 'NNP'), 1549),
#  (('WASHINGTON', 'NNP'), 1543),
#  (('Fund', 'NNP'), 1542),
#  (('IN', 'NNP'), 1539),
#  (('Beach', 'NNP'), 1538),
#  (('August', 'NNP'), 1535),
#  (('Division', 'NNP'), 1529),
#  (('Indiana', 'NNP'), 1526),
#  (('Europe', 'NNP'), 1519),
#  (('Mark', 'NNP'), 1516),
#  (('Esq', 'NNP'), 1514),
#  (('CPUC', 'NNP'), 1509),
#  (('INC', 'NNP'), 1506),
#  (('N.', 'NNP'), 1504),
#  (('Information', 'NNP'), 1503),
#  (('Avenue', 'NNP'), 1500),
#  (('Ave.', 'NNP'), 1494),
#  (('P.', 'NNP'), 1482),
#  (('O', 'NNP'), 1482),
#  (('Internet', 'NNP'), 1469),
#  (('Page', 'NNP'), 1461),
#  (('Oklahoma', 'NNP'), 1460),
#  (('Express', 'NNP'), 1459),
#  (('Newspapers', 'NNP'), 1450),
#  (('LP', 'NNP'), 1441),
#  (('E', 'NNP'), 1436),
#  (('Chicago', 'NNP'), 1433),
#  (('V.', 'NNP'), 1432),
#  (('Holdings', 'NNP'), 1431),
#  (('Party', 'NNP'), 1429),
#  (('Martin', 'NNP'), 1420),
#  (('N/A', 'NNP'), 1419),
#  (('See', 'NNP'), 1414),
#  (('Wisconsin', 'NNP'), 1410),
#  (('Joseph', 'NNP'), 1407),
#  (('VAN', 'NNP'), 1401),
#  (('Doc', 'NNP'), 1400),
#  (('Utility', 'NNP'), 1397),
#  (('Union', 'NNP'), 1393),
#  (('Lane', 'NNP'), 1393),
#  (('CALIF', 'NNP'), 1392),
#  (('Technologies', 'NNPS'), 1388),
#  (('Data', 'NNP'), 1385),
#  (('Code', 'NNP'), 1383),
#  (('EURO', 'NNP'), 1377),
#  (('Notice', 'NNP'), 1368),
#  (('OR', 'NNP'), 1367),
#  (('Services', 'NNP'), 1366),
#  (('Southern', 'NNP'), 1362),
#  (('Williams', 'NNP'), 1360),
#  (('U.S.C', 'NNP'), 1352),
#  (('Central', 'NNP'), 1350),
#  (('Virginia', 'NNP'), 1346),
#  (('Scott', 'NNP'), 1343),
#  (('River', 'NNP'), 1341),
#  (('A.', 'NNP'), 1338),
#  (('Water', 'NNP'), 1336),
#  (('Northern', 'NNP'), 1334),
#  (('Law', 'NNP'), 1333),
#  (('Securities', 'NNP'), 1326),
#  (('Systems', 'NNPS'), 1325),
#  (('William', 'NNP'), 1324),
#  (('Club', 'NNP'), 1323),
#  (('Supp', 'NNP'), 1322),
#  (('Police', 'NNP'), 1316),
#  (('Pennsylvania', 'NNP'), 1314),
#  (('Harris', 'NNP'), 1312),
#  (('Investor', 'NNP'), 1310),
#  (('Anderson', 'NNP'), 1301),
#  (('Lee', 'NNP'), 1301),
#  (('Stanley', 'NNP'), 1300),
#  (('Ms.', 'NNP'), 1298),
#  (('Network', 'NNP'), 1297),
#  (('III', 'NNP'), 1295),
#  (('F.R.D', 'NNP'), 1288),
#  (('Journal', 'NNP'), 1284),
#  (('Defendants', 'NNP'), 1281),
#  (('Richard', 'NNP'), 1277),
#  (('Carolina', 'NNP'), 1276),
#  (('Care', 'NNP'), 1275),
#  (('REGULATORY', 'NNP'), 1273),
#  (('CFR', 'NNP'), 1272),
#  (('Missouri', 'NNP'), 1270),
#  (('Vice', 'NNP'), 1268),
#  (('Secretary', 'NNP'), 1261),
#  (('Herald', 'NNP'), 1261),
#  (('Bay', 'NNP'), 1260),
#  (('Mary', 'NNP'), 1256),
#  (('K', 'NNP'), 1255),
#  (('PACIFIC', 'NNP'), 1249),
#  (('Green', 'NNP'), 1247),
#  (('NESS', 'NNP'), 1243),
#  (('SOLAR', 'NNP'), 1229),
#  (('Partners', 'NNPS'), 1223),
#  (('Pacific', 'NNP'), 1221),
#  (('Review', 'NNP'), 1221),
#  (('IT', 'NNP'), 1216),
#  (('Day', 'NNP'), 1215),
#  (('AREA', 'NNP'), 1215),
#  (('Government', 'NNP'), 1209),
#  (('Michigan', 'NNP'), 1190),
#  (('System', 'NNP'), 1189),
#  (('SERVICE', 'NNP'), 1185),
#  (('Sec', 'NNP'), 1173),
#  (('G', 'NNP'), 1172),
#  (('Staff', 'NNP'), 1172),
#  (('Charles', 'NNP'), 1167),
#  (('Los', 'NNP'), 1166),
#  (('Attorney', 'NNP'), 1161),
#  (('Ireland', 'NNP'), 1157),
#  (('Fed', 'NNP'), 1151),
#  (('Rights', 'NNPS'), 1149),
#  (('Church', 'NNP'), 1147),
#  (('Facebook', 'NNP'), 1143),
#  (('Francisco', 'NNP'), 1143),
#  (('Hospital', 'NNP'), 1142),
#  (('Nov.', 'NNP'), 1141),
#  (('Boston', 'NNP'), 1137),
#  (('BOX', 'NNP'), 1137),
#  (('Hill', 'NNP'), 1136),
#  (('Japan', 'NNP'), 1135),
#  (('Judge', 'NNP'), 1133),
#  (('PO', 'NNP'), 1133),
#  (('UTILITY', 'NNP'), 1132),
#  (('B.', 'NNP'), 1130),
#  (('LAW', 'NNP'), 1122),
#  (('NO', 'NNP'), 1120),
#  (('Colorado', 'NNP'), 1107),
#  (('St', 'NNP'), 1106),
#  (('Foods', 'NNP'), 1102),
#  (('Mike', 'NNP'), 1099),
#  (('Utilities', 'NNPS'), 1099),
#  (('Hazleton', 'NNP'), 1093),
#  (('Retail', 'NNP'), 1092),
#  (('CITY', 'NNP'), 1092),
#  (('Senior', 'NNP'), 1090),
#  (('AT', 'NNP'), 1090),
#  (('PARK', 'NNP'), 1089),
#  (('Estate', 'NNP'), 1085),
#  (('Consumer', 'NNP'), 1082),
#  (('Year', 'NNP'), 1080),
#  (('England', 'NNP'), 1079),
#  (('Conference', 'NNP'), 1077),
#  (('Communications', 'NNP'), 1076),
#  (('George', 'NNP'), 1073),
#  (('Holdings', 'NNPS'), 1070),
#  (('Key', 'NNP'), 1069),
#  (('Hall', 'NNP'), 1064),
#  (('AVE.', 'NNP'), 1064),
#  (('Time', 'NNP'), 1063),
#  (('PM', 'NNP'), 1061),
#  (('Plan', 'NNP'), 1060),
#  (('Chairman', 'NNP'), 1059),
#  (('Austin', 'NNP'), 1057),
#  (('GMT', 'NNP'), 1050),
#  (('Microsoft', 'NNP'), 1048),
#  (('Hawkins', 'NNP'), 1048),
#  (('Stock', 'NNP'), 1046),
#  (('Markets', 'NNP'), 1039),
#  (('White', 'NNP'), 1036),
#  (('MARKET', 'NNP'), 1033),
#  (('Program', 'NNP'), 1031),
#  (('Peter', 'NNP'), 1030),
#  (('Google', 'NNP'), 1028),
#  (('NEW', 'NNP'), 1028),
#  (('Project', 'NNP'), 1027),
#  (('Mrs', 'NNP'), 1025),
#  (('Oil', 'NNP'), 1024),
#  (('Credit', 'NNP'), 1024),
#  (('Trade', 'NNP'), 1020),
#  (('Defendant', 'NNP'), 1020),
#  (('Tom', 'NNP'), 1020),
#  (('Andrew', 'NNP'), 1017),
#  (('REGIONAL', 'NNP'), 1017),
#  (('Rate', 'NNP'), 1016),
#  (('Cal', 'NNP'), 1015),
#  (('Pipeline', 'NNP'), 1005),
#  (('Rs', 'NNP'), 1003),
#  (('Index', 'NNP'), 1002),
#  (('FCC', 'NNP'), 1002),
#  (('PUBLICATION-TYPE', 'NNP'), 1001),
#  (('Standard', 'NNP'), 1001),
#  (('App', 'NNP'), 1001),
#  (('Arkansas', 'NNP'), 1001),
#  (('POWER', 'NNP'), 998),
#  (('Christmas', 'NNP'), 996),
#  (('Complaint', 'NNP'), 995),
#  (('Supreme', 'NNP'), 995),
#  (('Foundation', 'NNP'), 995),
#  (('Area', 'NNP'), 991),
#  (('Black', 'NNP'), 988),
#  (('Sun', 'NNP'), 986),
#  (('W', 'NNP'), 986),
#  (('Securities', 'NNPS'), 985),
#  (('Louisiana', 'NNP'), 985),
#  (('Bureau', 'NNP'), 984),
#  (('Independent', 'NNP'), 983),
#  (('Mexico', 'NNP'), 979),
#  (('Van', 'NNP'), 977),
#  (('AMERICAN', 'NNP'), 977),
#  (('Life', 'NNP'), 973),
#  (('Jr.', 'NNP'), 971),
#  (('Education', 'NNP'), 969),
#  (('POLICY', 'NNP'), 969),
#  (('King', 'NNP'), 965),
#  (('Worldwide', 'NNP'), 965),
#  (('NY', 'NNP'), 965),
#  (('Chris', 'NNP'), 964),
#  (('Total', 'NNP'), 961),
#  (('Macy', 'NNP'), 958),
#  (('Amazon', 'NNP'), 958),
#  (('Institute', 'NNP'), 957),
#  (('Duke', 'NNP'), 948),
#  (('Louis', 'NNP'), 945),
#  (('DISTRICT', 'NNP'), 941),
#  (('Eastern', 'NNP'), 940),
#  (('Bill', 'NNP'), 939),
#  (('Certification', 'NNP'), 938),
#  (('NATIONAL', 'NNP'), 937),
#  (('Real', 'NNP'), 937),
#  (('Dow', 'NNP'), 934),
#  (('Systems', 'NNP'), 933),
#  (('ECF', 'NNP'), 932),
#  (('Deal', 'NNP'), 931),
#  (('G.', 'NNP'), 925),
#  (('Ford', 'NNP'), 924),
#  (('Food', 'NNP'), 923),
#  (('Royal', 'NNP'), 923),
#  (('Authority', 'NNP'), 923),
#  (('Legal', 'NNP'), 921),
#  (('Big', 'NNP'), 914),
#  (('Twitter', 'NNP'), 911),
#  (('COALITION', 'NNP'), 909),
#  (('Ann', 'NNP'), 907),
#  (('Morris', 'NNP'), 906),
#  (('OAKLAND', 'NNP'), 905),
#  (('League', 'NNP'), 904),
#  (('SOUTHERN', 'NNP'), 903),
#  (('PART', 'NNP'), 902),
#  (('Jim', 'NNP'), 901),
#  (('T.', 'NNP'), 897),
#  (('Santa', 'NNP'), 896),
#  (('LIST', 'NNP'), 895),
#  (('Manager', 'NNP'), 894),
#  (('Reports', 'NNP'), 892),
#  (('Asia', 'NNP'), 891),
#  (('Natural', 'NNP'), 884),
#  (('Steve', 'NNP'), 883),
#  (('Wilson', 'NNP'), 881),
#  (('Angeles', 'NNP'), 880),
#  (('Industrial', 'NNP'), 879),
#  (('Section', 'NNP'), 879),
#  (('Miller', 'NNP'), 874),
#  (('Price', 'NNP'), 869),
#  (('Line', 'NNP'), 867),
#  (('Georgia', 'NNP'), 865),
#  (('CENTER', 'NNP'), 864),
#  (('Pharma', 'NNP'), 863),
#  (('Nasdaq', 'NNP'), 862),
#  (('DC', 'NNP'), 857),
#  (('Pty', 'NNP'), 854),
#  (('EDITION', 'NNP'), 853),
#  (('Daniel', 'NNP'), 850),
#  (('Wall', 'NNP'), 850),
#  (('Davis', 'NNP'), 849),
#  (('Columbia', 'NNP'), 849),
#  (('Resources', 'NNPS'), 848),
#  (('Digital', 'NNP'), 848),
#  (('Bancorp', 'NNP'), 848),
#  (('Operations', 'NNP'), 841),
#  (('Commerce', 'NNP'), 841),
#  (('Maryland', 'NNP'), 839),
#  (('Properties', 'NNP'), 838),
#  (('Q', 'NNP'), 838),
#  (('Support', 'NNP'), 836),
#  (('Mills', 'NNP'), 832),
#  (('Industry', 'NNP'), 830),
#  (('Fourth', 'NNP'), 829),
#  (('FL', 'NNP'), 829),
#  (('FLOOR', 'NNP'), 827),
#  (('Administration', 'NNP'), 826),
#  (('NASDAQ', 'NNP'), 826),
#  (('El', 'NNP'), 826),
#  (('Jersey', 'NNP'), 823),
#  (('Third', 'NNP'), 823),
#  (('EDISON', 'NNP'), 822),
#  (('Suite', 'NNP'), 819),
#  (('x', 'NNP'), 819),
#  (('H.', 'NNP'), 818),
#  (('Point', 'NNP'), 817),
#  (('ASBESTOS', 'NNP'), 817),
#  (('Africa', 'NNP'), 816),
#  (('Economic', 'NNP'), 815),
#  (('____________________________________________', 'NNP'), 814),
#  (('Brian', 'NNP'), 812),
#  (('Wells', 'NNP'), 812),
#  (('Current', 'NNP'), 811),
#  (('La', 'NNP'), 811),
#  (('Island', 'NNP'), 806),
#  (('Sports', 'NNP'), 806),
#  (('Mail', 'NNP'), 806),
#  (('Denver', 'NNP'), 806),
#  (('Â·', 'NNP'), 806),
#  (('Barbie', 'NNP'), 806),
#  (('Lead', 'NNP'), 802),
#  (('Kelly', 'NNP'), 800),
#  (('Massachusetts', 'NNP'), 798),
#  (('Red', 'NNP'), 797),
#  (('Family', 'NNP'), 796),
#  (('Fla.', 'NNP'), 793),
#  (('Main', 'NNP'), 792),
#  (('Jan', 'NNP'), 792),
#  (('Pittsburgh', 'NNP'), 787),
#  (('Ms', 'NNP'), 783),
#  (('Equity', 'NNP'), 782),
#  (('ROOM', 'NNP'), 780),
#  (('Contact', 'NNP'), 777),
#  (('COUNSEL', 'NNP'), 777),
#  (('Hills', 'NNP'), 774),
#  (('Taylor', 'NNP'), 774),
#  (('Vol', 'NNP'), 773),
#  (('Security', 'NNP'), 772),
#  (('Eric', 'NNP'), 772),
#  (('F', 'NNP'), 770),
#  (('Final', 'NNP'), 770),
#  (('DIRECTOR', 'NNP'), 770),
#  (('F.2d', 'NNP'), 769),
#  (('Kevin', 'NNP'), 769),
#  (('McDonald', 'NNP'), 766),
#  (('Jason', 'NNP'), 764),
#  (('CCDF', 'NNP'), 763),
#  (('Mountain', 'NNP'), 761),
#  (('Transportation', 'NNP'), 757),
#  (('Fort', 'NNP'), 756),
#  (('Ryan', 'NNP'), 755),
#  (('Resources', 'NNP'), 754),
#  (('Publishing', 'NNP'), 753),
#  (('Bob', 'NNP'), 752),
#  (('Software', 'NNP'), 749),
#  (('Counsel', 'NNP'), 749),
#  (('Progressive', 'NNP'), 747),
#  (('Creek', 'NNP'), 747),
#  (('Western', 'NNP'), 747),
#  (('K.', 'NNP'), 746),
#  (('HP', 'NNP'), 746),
#  (('Type', 'NNP'), 745),
#  (('Jackson', 'NNP'), 744),
#  (('Mass', 'NNP'), 741),
#  (('Congress', 'NNP'), 734),
#  (('Application', 'NNP'), 734),
#  (('DIVISION', 'NNP'), 732),
#  (('Carter', 'NNP'), 727),
#  (('Regional', 'NNP'), 725),
#  (('Head', 'NNP'), 725),
#  (('Growth', 'NNP'), 722),
#  (('Coast', 'NNP'), 722),
#  (('CLEAN', 'NNP'), 720),
#  (('NOI', 'NNP'), 719),
#  (('Commercial', 'NNP'), 716),
#  (('Madison', 'NNP'), 716),
#  (('DRIVE', 'NNP'), 716),
#  (('Centre', 'NNP'), 715),
#  (('Comcast', 'NNP'), 715),
#  (('Great', 'NNP'), 714),
#  (('OFFICE', 'NNP'), 714),
#  (('Old', 'NNP'), 713),
#  (('IBM', 'NNP'), 712),
#  (('Brunswick', 'NNP'), 711),
#  (('Agencies', 'NNPS'), 710),
#  (('Hotel', 'NNP'), 707),
#  (('Industries', 'NNPS'), 706),
#  (('Elizabeth', 'NNP'), 705),
#  (('Tech', 'NNP'), 705),
#  (('Jack', 'NNP'), 704),
#  (('Banking', 'NNP'), 704),
#  (('L.P.', 'NNP'), 701),
#  (('Philadelphia', 'NNP'), 699),
#  (('Tim', 'NNP'), 699),
#  (('Joe', 'NNP'), 698),
#  (('Atlanta', 'NNP'), 697),
#  (('YORK', 'NNP'), 697),
#  (('Tesco', 'NNP'), 696),
#  (('Schedule', 'NNP'), 695),
#  (('Christopher', 'NNP'), 694),
#  (('Township', 'NNP'), 693),
#  (('Force', 'NNP'), 692),
#  (('Lewis', 'NNP'), 691),
#  (('Victoria', 'NNP'), 689),
#  (('DIR', 'NNP'), 689),
#  (('CORPORATION', 'NNP'), 687),
#  (('Blue', 'NNP'), 687),
#  (('EBITDA', 'NNP'), 685),
#  (('Safety', 'NNP'), 683),
#  (('Reserve', 'NNP'), 682),
#  (('WALNUT', 'NNP'), 682),
#  (('AG', 'NNP'), 680),
#  (('Middle', 'NNP'), 680),
#  (('BUSINESS', 'NNP'), 679),
#  (('Edison', 'NNP'), 678),
#  (('Young', 'NNP'), 677),
#  (('WATER', 'NNP'), 677),
#  (('Markets', 'NNPS'), 676),
#  (('Companies', 'NNP'), 676),
#  (('Barnes', 'NNP'), 676),
#  (('Committee', 'NNP'), 675),
#  (('Property', 'NNP'), 673),
#  (('H', 'NNP'), 667),
#  (('Corporate', 'NNP'), 666),
#  (('Campbell', 'NNP'), 666),
#  (('WEST', 'NNP'), 666),
#  (('Starbucks', 'NNP'), 663),
#  (('Intel', 'NNP'), 661),
#  (('Moody', 'NNP'), 660),
#  (('LOS', 'NNP'), 660),
#  (('GE', 'NNP'), 658),
#  (('Town', 'NNP'), 657),
#  (('Best', 'NNP'), 657),
#  (('Part', 'NNP'), 655),
#  (('Fargo', 'NNP'), 655),
#  (('Way', 'NNP'), 654),
#  (('PageID', 'NNP'), 653),
#  (('Brady', 'NNP'), 653),
#  (('Litig.', 'NNP'), 651),
#  (('Protection', 'NNP'), 649),
#  (('Detroit', 'NNP'), 647),
#  (('Dr', 'NNP'), 646),
#  (('Sept.', 'NNP'), 644),
#  (('Action', 'NNP'), 644),
#  (('Tampa', 'NNP'), 644),
#  (('Amendment', 'NNP'), 643),
#  (('Exhibit', 'NNP'), 642),
#  (('Iowa', 'NNP'), 641),
#  (('Direct', 'NNP'), 641),
#  (('Grand', 'NNP'), 640),
#  (('Homes', 'NNP'), 639),
#  (('Investing.com', 'NNP'), 639),
#  (('Civ', 'NNP'), 638),
#  (('Children', 'NNP'), 638),
#  (('Policy', 'NNP'), 637),
#  (('Oct.', 'NNP'), 635),
#  (('Steel', 'NNP'), 635),
#  (('Anthony', 'NNP'), 634),
#  (('Award', 'NNP'), 634),
#  (('Annual', 'NNP'), 634),
#  (('Dayton', 'NNP'), 634),
#  (('Mo', 'NNP'), 633),
#  (('Clark', 'NNP'), 633),
#  (('COURT', 'NNP'), 632),
#  (('Aaron', 'NNP'), 632),
#  (('Good', 'NNP'), 631),
#  (('Jose', 'NNP'), 631),
#  (('Frank', 'NNP'), 631),
#  (('Armour', 'NNP'), 631),
#  (('Steven', 'NNP'), 630),
#  (('Science', 'NNP'), 629),
#  (('JOURNAL-CODE', 'NNP'), 629),
#  (('Society', 'NNP'), 627),
#  (('Alliance', 'NNP'), 627),
#  (('Obama', 'NNP'), 627),
#  (('Memorial', 'NNP'), 627),
#  (('Jeff', 'NNP'), 626),
#  (('Enterprises', 'NNP'), 625),
#  (('Second', 'NNP'), 625),
#  (('Kansas', 'NNP'), 625),
#  (('Eagle', 'NNP'), 625),
#  (('PLC', 'NNP'), 625),
#  (('Mississippi', 'NNP'), 624),
#  (('Las', 'NNP'), 623),
#  (('Christian', 'NNP'), 623),
#  (('Products', 'NNPS'), 623),
#  (('Record', 'NNP'), 623),
#  (('Aug.', 'NNP'), 623),
#  (('PDF', 'NNP'), 623),
#  (('Rosen', 'NNP'), 623),
#  (('Wal-Mart', 'NNP'), 617),
#  (('Gold', 'NNP'), 616),
#  (('Phase', 'NNP'), 615),
#  (('Construction', 'NNP'), 615),
#  (('Germany', 'NNP'), 614),
#  (('Singapore', 'NNP'), 614),
#  (('Mayor', 'NNP'), 614),
#  (('MetLife', 'NNP'), 614),
#  (('Chipotle', 'NNP'), 613),
#  (('§', 'NNP'), 612),
#  (('Orange', 'NNP'), 612),
#  (('Country', 'NNP'), 611),
#  (('Unit', 'NNP'), 609),
#  (('Jennifer', 'NNP'), 608),
#  (('Environmental', 'NNP'), 606),
#  (('Asset', 'NNP'), 606),
#  (('Palm', 'NNP'), 606),
#  (('Directors', 'NNP'), 605),
#  (('HIGHLIGHT', 'NNP'), 605),
#  (('ANGELES', 'NNP'), 605),
#  (('ASSOCIATION', 'NNP'), 605),
#  (('Matthew', 'NNP'), 603),
#  (('Matt', 'NNP'), 602),
#  (('Revenue', 'NNP'), 602),
#  (('Minister', 'NNP'), 602),
#  (('Mortgage', 'NNP'), 600),
#  (('Alpine', 'NNP'), 599),
#  (('Tiffany', 'NNP'), 597),
#  (('Urban', 'NNP'), 597),
#  (('Ill.', 'NNP'), 596),
#  (('SEC', 'NNP'), 596),
#  (('Series', 'NNP'), 595),
#  (('Telegraph', 'NNP'), 595),
#  (('Automotive', 'NNP'), 594),
#  (('BERKELEY', 'NNP'), 594),
#  (('Finance', 'NNP'), 592),
#  (('Allen', 'NNP'), 592),
#  (('Pvt', 'NNP'), 590),
#  (('Bell', 'NNP'), 590),
#  (('Stephen', 'NNP'), 589),
#  (('ROSEMEAD', 'NNP'), 588),
#  (('Analysis', 'NNP'), 587),
#  (('Goldman', 'NNP'), 586),
#  (('Supply', 'NNP'), 585),
#  (('N.D.', 'NNP'), 584),
#  (('France', 'NNP'), 583),
#  (('Quarter', 'NNP'), 583),
#  (('Fire', 'NNP'), 583),
#  (('CENTURY', 'NNP'), 583),
#  (('Plaza', 'NNP'), 582),
#  (('GROVE', 'NNP'), 582),
#  (('Description', 'NNP'), 580),
#  (('Ex', 'NNP'), 578),
#  (('Motion', 'NNP'), 578),
#  (('Core', 'NNP'), 578),
#  (('Moore', 'NNP'), 577),
#  (('Academy', 'NNP'), 576),
#  (('N.C.', 'NNP'), 575),
#  (('Chemical', 'NNP'), 574),
#  (('Brands', 'NNP'), 573),
#  (('Fred', 'NNP'), 573),
#  (('Fidelity', 'NNP'), 572),
#  (('CO', 'NNP'), 571),
#  (('A.M.', 'NNP'), 571),
#  (('Pharmaceuticals', 'NNP'), 570),
#  (('Dan', 'NNP'), 570),
#  (('Syndigate', 'NNP'), 569),
#  (('GROUP', 'NNP'), 569),
#  (('Holding', 'NNP'), 569),
#  (('ON', 'NNP'), 568),
#  (('Register', 'NNP'), 567),
#  (('Bennett', 'NNP'), 567),
#  (('Auto', 'NNP'), 567),
#  (('ENERGY,2016', 'NNP'), 567),
#  (('Unofficial', 'NNP'), 565),
#  (('V', 'NNP'), 564),
#  (('Tower', 'NNP'), 563),
#  (('Thompson', 'NNP'), 562),
#  (('Marketing', 'NNP'), 561),
#  (('Falls', 'NNP'), 560),
#  (('DAVID', 'NNP'), 560),
#  (('Arizona', 'NNP'), 559),
#  (('Diagnostics', 'NNPS'), 559),
#  (('Toronto', 'NNP'), 559),
#  (('S.D', 'NNP'), 557),
#  (('Please', 'NNP'), 555),
#  (('VALLEY', 'NNP'), 555),
#  (('Huntington', 'NNP'), 555),
#  (('Investments', 'NNP'), 554),
#  (('Tyco', 'NNP'), 554),
#  (('Southwest', 'NNP'), 554),
#  (('MN', 'NNP'), 553),
#  (('Enterprise', 'NNP'), 553),
#  (('Philip', 'NNP'), 553),
#  (('Super', 'NNP'), 553),
#  (('CORP', 'NNP'), 552),
#  (('File', 'NNP'), 552),
#  (('VA', 'NNP'), 552),
#  (('JAMES', 'NNP'), 550),
#  (('Response', 'NNP'), 549),
#  (('E.D', 'NNP'), 549),
#  (('Show', 'NNP'), 548),
#  (('NC', 'NNP'), 548),
#  (('Funeral', 'NNP'), 548),
#  (('Bowl', 'NNP'), 548),
#  (('ROAD', 'NNP'), 548),
#  (('Plc', 'NNP'), 547),
#  (('Adam', 'NNP'), 546),
#  (('Local', 'NNP'), 546),
#  (('AFFAIRS', 'NNP'), 546),
#  (('Dover', 'NNP'), 546),
#  (('Stryker', 'NNP'), 544),
#  (('FSS', 'NNP'), 544),
#  (('Minneapolis', 'NNP'), 543),
#  (('Queen', 'NNP'), 543),
#  (('Grove', 'NNP'), 543),
#  (('JPMorgan', 'NNP'), 543),
#  (('Yahoo', 'NNP'), 543),
#  (('Houston', 'NNP'), 542),
#  (('God', 'NNP'), 542),
#  (('Target', 'NNP'), 541),
#  (('Fisher', 'NNP'), 540),
#  (('Noble', 'NNP'), 539),
#  (('Mason', 'NNP'), 538),
#  (('FORM', 'NNP'), 537),
#  (('Palmer', 'NNP'), 537),
#  (('Airlines', 'NNPS'), 537),
#  (('Mount', 'NNP'), 536),
#  (('Dakota', 'NNP'), 536),
#  (('Mobile', 'NNP'), 534),
#  (('Army', 'NNP'), 534),
#  (('Delaware', 'NNP'), 533),
#  (('Hong', 'NNP'), 533),
#  (('Cup', 'NNP'), 533),
#  (('Shippers', 'NNP'), 532),
#  (('Petroleum', 'NNP'), 532),
#  (('Building', 'NNP'), 531),
#  (('Woodward', 'NNP'), 531),
#  (('Calif.', 'NNP'), 531),
#  (('Chase', 'NNP'), 530),
#  (('NRG', 'NNP'), 530),
#  (('Address', 'NNP'), 529),
#  (('Outlook', 'NNP'), 529),
#  (('Grant', 'NNP'), 529),
#  (('CASE', 'NNP'), 529),
#  (('CAPITOL', 'NNP'), 529),
#  (('Channel', 'NNP'), 528),
#  (('Stat', 'NNP'), 526),
#  (('Partnership', 'NNP'), 526),
#  (('Library', 'NNP'), 526),
#  (('Ontario', 'NNP'), 523),
#  (('Boulder', 'NNP'), 523),
#  (('Place', 'NNP'), 522),
#  (('Hamilton', 'NNP'), 522),
#  (('Chamber', 'NNP'), 522),
#  (('Cancer', 'NNP'), 521),
#  (('Fitch', 'NNP'), 521),
#  (('Gary', 'NNP'), 519),
#  (('SourceMedia', 'NNP'), 519),
#  (('Practices', 'NNP'), 518),
#  (('Tennessee', 'NNP'), 517),
#  (('Patrick', 'NNP'), 517),
#  (('BY', 'NNP'), 517),
#  (('Ben', 'NNP'), 516),
#  (('Loan', 'NNP'), 516),
#  (('Museum', 'NNP'), 515),
#  (('ET', 'NNP'), 515),
#  (('Commissioner', 'NNP'), 515),
#  (('Prior', 'NNP'), 514),
#  (('D.C.', 'NNP'), 513),
#  (('Baker', 'NNP'), 513),
#  (('Universal', 'NNP'), 513),
#  (('Editor', 'NNP'), 512),
#  (('Nick', 'NNP'), 512),
#  (('Donald', 'NNP'), 510),
#  (('Filing', 'NNP'), 510),
#  (('SA', 'NNP'), 509),
#  (('Cost', 'NNP'), 509),
#  (('Simon', 'NNP'), 508),
#  (('Products', 'NNP'), 507),
#  (('GAAP', 'NNP'), 507),
#  (('Equipment', 'NNP'), 507),
#  (('CUSTOMER', 'NNP'), 507),
#  (('FINANCIAL', 'NNP'), 506),
#  (('Justice', 'NNP'), 506),
#  (('Douglas', 'NNP'), 506),
#  (('Controls', 'NNP'), 506),
#  (('NETWORK', 'NNP'), 506),
#  (('Summary', 'NNP'), 505),
#  (('Port', 'NNP'), 504),
#  (('Zealand', 'NNP'), 504),
#  (('Mitchell', 'NNP'), 504),
#  (('Associated', 'NNP'), 503),
#  (('___', 'NNP'), 503),
#  (('Open', 'NNP'), 503),
#  (('Announces', 'NNP'), 503),
#  (('SUSTAINABLE', 'NNP'), 503),
#  (('Entergy', 'NNP'), 503),
#  (('Industries', 'NNP'), 502),
#  (('Distribution', 'NNP'), 502),
#  (('Square', 'NNP'), 502),
#  (('Pa.', 'NNP'), 502),
#  (('Women', 'NNP'), 501),
#  (('Rd.', 'NNP'), 501),
#  (('Vancouver', 'NNP'), 500),
#  (('SMITH', 'NNP'), 500),
#  (('Connecticut', 'NNP'), 499),
#  (('Art', 'NNP'), 499),
#  (('Sachs', 'NNP'), 497),
#  (('Coleman', 'NNP'), 496),
#  (('ELECTRICITY', 'NNP'), 496),
#  (('Bayer', 'NNP'), 495),
#  (('Wood', 'NNP'), 495),
#  (('LEGAL', 'NNP'), 494),
#  (('Dave', 'NNP'), 494),
#  (('Queensland', 'NNP'), 494),
#  (('Farm', 'NNP'), 494),
#  (('Dick', 'NNP'), 494),
#  (('Warner', 'NNP'), 493),
#  (('Village', 'NNP'), 493),
#  (('Hess', 'NNP'), 493),
#  (('Airport', 'NNP'), 492),
#  (('Kong', 'NNP'), 492),
#  (('Consolidated', 'NNP'), 492),
#  (('BLVD', 'NNP'), 492),
#  (('CONSULTING', 'NNP'), 491),
#  (('Laboratories', 'NNPS'), 490),
#  (('Jordan', 'NNP'), 489),
#  (('TX', 'NNP'), 489),
#  (('Opp', 'NNP'), 489),
#  (('Rev', 'NNP'), 488),
#  (('Item', 'NNP'), 488),
#  (('Transmission', 'NNP'), 486),
#  (('Walker', 'NNP'), 485),
#  (('Br', 'NNP'), 485),
#  (('Scotland', 'NNP'), 484),
#  (('Pioneer', 'NNP'), 484),
#  (('Sam', 'NNP'), 484),
#  (('Administrative', 'NNP'), 482),
#  (('Burke', 'NNP'), 482),
#  (('Control', 'NNP'), 482),
#  (('PA', 'NNP'), 482),
#  (('Income', 'NNP'), 482),
#  (('MC', 'NNP'), 482),
#  (('Ark', 'NNP'), 481),
#  (('Station', 'NNP'), 480),
#  (('Kentucky', 'NNP'), 480),
#  (('Oak', 'NNP'), 480),
#  (('Electronic', 'NNP'), 479),
#  (('Mall', 'NNP'), 479),
#  (('Gulf', 'NNP'), 479),
#  (('Verizon', 'NNP'), 479),
#  (('Design', 'NNP'), 478),
#  (('Britain', 'NNP'), 478),
#  (('Highway', 'NNP'), 478),
#  (('Delhi', 'NNP'), 477),
#  (('Clinton', 'NNP'), 477),
#  (('Paso', 'NNP'), 477),
#  (('Dollar', 'NNP'), 476),
#  (('Engineering', 'NNP'), 475),
#  (('Contract', 'NNP'), 475),
#  (('Small', 'NNP'), 475),
#  (('Fifth', 'NNP'), 475),
#  (('Def', 'NNP'), 475),
#  (('Americans', 'NNPS'), 474),
#  ...]

# %%
tag_freq.plot(30)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
